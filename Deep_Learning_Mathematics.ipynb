# %% [markdown]
# <a href="https://colab.research.google.com/github/Centicini/AMR-Prediction-Single-Bacterial-Strain/blob/main/Deep_Learning_Mathematics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report, precision_score, recall_score

# %%
print("Welcome to this coding tutorial")
# Out:
# Welcome to this coding tutorial

# %%
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# #### Some Practice

# %%
#Scaler

a = np.array(5)
print("Scaler:", a)
print("Shape:", a.shape)
# Out:
# Scaler: 5
# Shape: ()

# %%
#Vector
b = np.array([1, 2, 3])
print("Vector:", b)
print("Shape:", b.shape)
# Out:
# Vector: [1 2 3]
# Shape: (3,)

# %%
c = np.array([
    [1, 2, 3],
    [4, 5, 6]
])

print("\nMatrix:")
print(c)
print("Shape:", c.shape)
# Out:
# Matrix:
# [[1 2 3]
#  [4 5 6]]
# Shape: (2, 3)

# %%
#3D Tensor

d = np.array([
    [[1, 2, 5, 6], [6, 6, 3, 4]],
    [[5, 4, 5, 6], [7, 8, 5, 4]]
])


print("\nTensor:")
print(d)
print("Shape:", d.shape)
# Out:
# Tensor:
# [[[1 2 5 6]
#   [6 6 3 4]]
#
#  [[5 4 5 6]
#   [7 8 5 4]]]
# Shape: (2, 2, 4)

# %%
x = np.array([2, -3, 4])
w = np.array([-5, -6, 6])


dot_result = np.dot(x, w)
print(dot_result)
# Out:
# 32

# %%
#Grayscale image

image = np.array([
    [0, 255],
    [128, 200]
])



print(image)
print(image.shape)
# Out:
# [[  0 255]
#  [128 200]]
# (2, 2)

# %%
#RGB Image

rgb_image = np.array([
    [[255, 0, 0], [0, 255, 0]],
    [[0, 0, 255], [255, 255, 0]]
])


print(rgb_image.shape)
# Out:
# (2, 2, 3)

# %%
#Let us perform some Basic Operations


x = np.array([1, 2, 3])
y = np.array([4, 5, 6])

results = x + y
print(results)
# Out:
# [5 7 9]

# %%
result = x *y

print(result)
# Out:
# [ 4 10 18]

# %%
#Scaler multiplication

print(x * 3)
# Out:
# [3 6 9]

# %%
x = np.array([1, 2, 3])
y = np.array([4, 5, 6])

dot = np.dot(x, y)
print(dot)
# Out:
# 32

# %%
A = np.array([
    [1, 2],
    [3, 4]
])

B = np.array([
    [5, 6],
    [7, 8]
])

result = np.dot(A, B)

print(result)
# Out:
# [[19 22]
#  [43 50]]

# %%
e = np.array([7, 8, 9])

z = e + 3

print(z)
# Out:
# [10 11 12]

# %%
data = np.array([10, 20, 30, 40])

print("Mean:", np.mean(data))
print("Std:", data.std())
# Out:
# Mean: 25.0
# Std: 11.180339887498949

# %%
t = tf.constant([1, 2, 3])

print(t)
# Out:
# tf.Tensor([1 2 3], shape=(3,), dtype=int32)

# %%
#Operations

a = tf.constant([1, 2, 3])
b = tf.constant([4, 5, 6])

print(a +  b)
# Out:
# tf.Tensor([5 7 9], shape=(3,), dtype=int32)

# %%
x = np.array([2, 3])
w = np.array([0.5, 1.5])
b = 1

z = np.dot(x, w) + b

print(z)
# Out:
# 6.5

# %%
def sigmoid(x):
  return 1 / (1 + np.exp(-x))

print(sigmoid(2))
# Out:
# 0.8807970779778823

# %%
y_true = np.array([1, 0, 1])
y_pred = np.array([0.8, 0.2, 0.6])


mse = np.mean((y_true - y_pred)**2)

print(mse
      )
# Out:
# 0.08

# %%
#Exercise
#createba scaler and print it's shape
d = np.array(4)

print("Shape:", d.shape)
print(d)
# Out:
# Shape: ()
# 4

# %%
fit = np.array([9, 0.4, 23.3, 22, 4])

print("Vector:", fit)
print("Shape of Vector:", fit.shape)
# Out:
# Vector: [ 9.   0.4 23.3 22.   4. ]
# Shape of Vector: (5,)

# %%
bmi = np.array([
    [12, 6, 3],
    [7, 12, 43],
    [6, 3, 6]
])

bmi.shape
# Out:
# (3, 3)

# %%
print("BMI position:\n", bmi)
# Out:
# BMI position:
#  [[12  6  3]
#  [ 7 12 43]
#  [ 6  3  6]]

# %%
#Print shape of [[1, 2], [3, 4], [5,6]]

tv = np.array([
    [[1, 2], [3, 4], [5, 6]]
])


print("tv shape:", tv.shape)
# Out:
# tv shape: (1, 3, 2)

# %%
#Vector Addition


num = np.array([1, 2, 3])
sop = np.array([10, 20, 30])


print(num + sop)


#this is element wise vector addition
# Out:
# [11 22 33]

# %%
print(num * 3)
# Out:
# [3 6 9]

# %%
print(sop** 3)
# Out:
# [ 1000  8000 27000]

# %%
#dot product
do_pro = np.dot(num, sop)

print(do_pro)
# Out:
# 140

# %%
sup = np.array([5, 10, 15, 20])

print(sup.mean())
# Out:
# 12.5

# %%
print(np.mean(sup))
# Out:
# 12.5

# %%
fake_grey =np.array([
    [255, 0, 0],
    [0, 255, 0],
    [255, 255, 0]
])


print(fake_grey.shape)
# Out:
# (3, 3)

# %%
rgb_imaging = np.array(
    [
    [[232, 67, 9], [89, 67, 23]],
    [[123, 3, 27], [23, 27, 234]]

    ]
)


print("Shape of the RGB Image", rgb_imaging.shape)
# Out:
# Shape of the RGB Image (2, 2, 3)

# %%
a = tf.constant(10)


 print(a.shape)
# Out:
# ()

# %%
b = tf.constant([1, 2, 3])

print(b.shape)
# Out:
# (3,)

# %%
c = tf.constant([[1, 2],
                 [3, 4]])


c.shape
# Out:
# TensorShape([2, 2])

# %%
#tensor (3D)

d = tf.constant([
    [[1, 2], [3, 4]],
    [[5,6], [7, 8]]
])


print("Scaler shape:", a.shape)
print("Vector Shape:", b.shape)
print("Matrix Shape:", c.shape)
print("Tensor shape:", d.shape)
# Out:
# Scaler shape: ()
# Vector Shape: (3,)
# Matrix Shape: (2, 2)
# Tensor shape: (2, 2, 2)

# %%
broke = tf.constant([
    [10, 20, 30],
    [40, 50, 60]
])

print(broke)
print("Shape:", broke.shape)
# Out:
# tf.Tensor(
# [[10 20 30]
#  [40 50 60]], shape=(2, 3), dtype=int32)
# Shape: (2, 3)

# %%
#first Row
x = tf.constant([
    [10, 20, 30],
    [40, 50, 60]
])



print(x[0])
# Out:
# tf.Tensor([10 20 30], shape=(3,), dtype=int32)

# %%
#to print Second row

print(x[1]
      )
# Out:
# tf.Tensor([40 50 60], shape=(3,), dtype=int32)

# %%
#element slicing second element in the first row

print(x[0][1])
# Out:
# tf.Tensor(20, shape=(), dtype=int32)

# %%
#Element wise operations for tensors


a = tf.constant([1, 2, 3])
b = tf.constant([4, 5, 6])

print(a + b)

print(a * b)
# Out:
# tf.Tensor([5 7 9], shape=(3,), dtype=int32)
# tf.Tensor([ 4 10 18], shape=(3,), dtype=int32)

# %%
a = tf.constant([1 , 2, 3])
b = tf.constant(2)


print(a + b)
# Out:
# tf.Tensor([3 4 5], shape=(3,), dtype=int32)

# %%
A = tf.constant([
    [32, 34],
    [23, 11],
    [34, 78]
])


B = tf.constant([
    [2, 4, 23],
    [34, 12, 36]
])


compute = tf.matmul(A, B)

print(compute)

#the rows(n) must match the columns(n)
# Out:
# tf.Tensor(
# [[1220  536 1960]
#  [ 420  224  925]
#  [2720 1072 3590]], shape=(3, 3), dtype=int32)

# %%
A = tf.constant([[1, 2, 3]])
B = tf.constant([[1, 2]])


#This will not run
#tf.matmul(A, B)

# %%
x = tf.constant([1, 2, 3, 4])
reshaped = tf.reshape(x, (2, 2))

print(reshaped)
# Out:
# tf.Tensor(
# [[1 2]
#  [3 4]], shape=(2, 2), dtype=int32)

# %%
x =tf.constant([1, 2, 3])


x_new = tf.expand_dims(x, axis=0)

print(x_new)
print(x_new.shape)
# Out:
# tf.Tensor([[1 2 3]], shape=(1, 3), dtype=int32)
# (1, 3)

# %%
#Reduction Operations


x = tf.constant([1, 2, 3, 4], dtype=tf.float32)
print('Sum:', tf.reduce_sum(x))
print('Mean:', tf.reduce_mean(x))
# Out:
# Sum: tf.Tensor(10.0, shape=(), dtype=float32)
# Mean: tf.Tensor(2.5, shape=(), dtype=float32)

# %%
#TENSORFLOW THINKING

x = tf.constant([[2.0, 3.0]])

# %%
x = tf.constant([[2.0, 3.0]]) #input
w = tf.constant([[0.5], [1.5]]) #weights

b = tf.constant([1.0]) #bias


z = tf.matmul(x, w) + b

print(z)
# Out:
# tf.Tensor([[6.5]], shape=(1, 1), dtype=float32)

# %%
#Exercises

#Creating a
# -scaler
# -vector
# -matrix

tom = tf.constant(13)
sam = tf.constant([23, 45, 21])
john = tf.constant([
    [23, 44, 21],
    [44, 2, 1]
])

print("Scaler Shape:", tom.shape)
print("Vector Shape:", sam.shape)
print("Matrix Shape:", john.shape)
# Out:
# Scaler Shape: ()
# Vector Shape: (3,)
# Matrix Shape: (2, 3)

# %%
boss = tf.constant([
    [10, 20],
    [30, 40],
    [50, 60]
])


print("Shape of Boss:", boss.shape)
# Out:
# Shape of Boss: (3, 2)

# %%
print("First row of boss:", boss[0])
print("Last element in first row of boss:", boss[0][-1 :])
# Out:
# First row of boss: tf.Tensor([10 20], shape=(2,), dtype=int32)
# Last element in row of boss: tf.Tensor([20], shape=(1,), dtype=int32)

# %%
pred = tf.constant([
    [1, 2, 3]
])

fed = tf.constant([
    [10, 20, 30]
])


print(fed + pred)
# Out:
# tf.Tensor([11 22 33], shape=(3,), dtype=int32)

# %%
print(fed * 3)
# Out:
# tf.Tensor([30 60 90], shape=(3,), dtype=int32)

# %%
#Broadcasting


print(pred + 7)
# Out:
# tf.Tensor([ 8  9 10], shape=(3,), dtype=int32)

# %%
#Matrix multiplication

u = tf.constant([
    [1, 2],
    [5, 8]

])


y = tf.constant([
    [45, 23],
    [2, 7]
])



print("Matrix Product\n:", tf.matmul(u, y))
# Out:
# Matrix Product
# : tf.Tensor(
# [[ 49  37]
#  [241 171]], shape=(2, 2), dtype=int32)

# %%
#Reshaping Values

mango = tf.constant([1, 2, 3, 4, 5, 6])

reshaper = tf.reshape(mango, (2, 3))
print(reshaper)
# Out:
# tf.Tensor(
# [[1 2 3]
#  [4 5 6]], shape=(2, 3), dtype=int32)

# %%
#Expand Dimension


york = tf.constant([1, 2, 3])

new_york =tf.expand_dims(york, axis=1)

print(new_york)
# Out:
# tf.Tensor(
# [[1]
#  [2]
#  [3]], shape=(3, 1), dtype=int32)

# %%
#Tensor Operations


zaid = tf.constant([10, 20, 30, 40])


print("sum is:", tf.reduce_sum(zaid))
print("Mean is:", tf.reduce_mean(zaid))
# Out:
# sum is: tf.Tensor(100, shape=(), dtype=int32)
# Mean is: tf.Tensor(25, shape=(), dtype=int32)

# %%
#To cast to float

numer = tf.constant([12, 34, 23],tf.dtypes.float32)

print("New Mean of numer is:", tf.reduce_mean(numer))
# Out:
# New Mean of numer is: tf.Tensor(23.0, shape=(), dtype=float32)
